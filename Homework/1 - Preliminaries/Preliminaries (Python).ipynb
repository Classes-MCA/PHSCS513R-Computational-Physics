# %% [markdown]
# # Problem 1: Plotting Generated Data

# %%
import numpy as np

# Plotting
import chart_studio.plotly as py
import plotly.express as px

# %%
x = np.linspace(0,2*np.pi,100)
y = np.exp(6*np.sin(x))

# %%
fig = px.line(x=x,y=y)

# Updating the format
fig.update_layout(
    title = {
        'text': "Example Plot 1",
        'y': 0.95,
        'x': 0.5,
        'xanchor': 'center',
        'yanchor': 'top',
        'font': dict(family = "Arial", size = 30)
    },
    xaxis = {
        'title': "x",
        'title_font': dict(family = "Arial", size = 24)
    },
    yaxis = {
        'title': "f(x)",
        'title_font': dict(family = "Arial", size = 24)
    })

# Woohoo this works!!!
fig.data[0].update(mode='markers+lines')

# This can change the color
# fig.data[0].update(line={'color':'green'})

# This can change the line color and thickness
fig.update_traces(line=dict(color="Green", width=4))

# This can change the marker color
fig.update_traces(marker=dict(color = "Green",size=10))

# This can change the background color
fig.update_layout({'plot_bgcolor': 'rgba(0, 0, 0, 0.1)','paper_bgcolor': 'rgba(0, 0, 0, 0)'})

fig.show()
#print(fig)
# Out:
# <div>                            <div id="4e5bed41-d955-40c1-a3ce-6e125ccc84f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e5bed41-d955-40c1-a3ce-6e125ccc84f4")) {                    Plotly.newPlot(                        "4e5bed41-d955-40c1-a3ce-6e125ccc84f4",                        [{"hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "Green", "dash": "solid", "width": 4}, "marker": {"color": "Green", "size": 10}, "mode": "markers+lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.0, 0.06346651825433926, 0.12693303650867852, 0.1903995547630178, 0.25386607301735703, 0.3173325912716963, 0.3807991095260356, 0.4442656277803748, 0.5077321460347141, 0.5711986642890533, 0.6346651825433925, 0.6981317007977318, 0.7615982190520711, 0.8250647373064104, 0.8885312555607496, 0.9519977738150889, 1.0154642920694281, 1.0789308103237674, 1.1423973285781066, 1.2058638468324459, 1.269330365086785, 1.3327968833411243, 1.3962634015954636, 1.4597299198498028, 1.5231964381041423, 1.5866629563584815, 1.6501294746128208, 1.71359599286716, 1.7770625111214993, 1.8405290293758385, 1.9039955476301778, 1.967462065884517, 2.0309285841388562, 2.0943951023931957, 2.1578616206475347, 2.221328138901874, 2.284794657156213, 2.3482611754105527, 2.4117276936648917, 2.475194211919231, 2.53866073017357, 2.6021272484279097, 2.6655937666822487, 2.729060284936588, 2.792526803190927, 2.8559933214452666, 2.9194598396996057, 2.982926357953945, 3.0463928762082846, 3.1098593944626236, 3.173325912716963, 3.236792430971302, 3.3002589492256416, 3.3637254674799806, 3.42719198573432, 3.490658503988659, 3.5541250222429985, 3.6175915404973376, 3.681058058751677, 3.744524577006016, 3.8079910952603555, 3.8714576135146945, 3.934924131769034, 3.998390650023373, 4.0618571682777125, 4.1253236865320515, 4.188790204786391, 4.25225672304073, 4.3157232412950695, 4.3791897595494085, 4.442656277803748, 4.506122796058087, 4.569589314312426, 4.6330558325667655, 4.696522350821105, 4.759988869075444, 4.823455387329783, 4.886921905584122, 4.950388423838462, 5.013854942092801, 5.07732146034714, 5.14078797860148, 5.204254496855819, 5.267721015110158, 5.331187533364497, 5.394654051618837, 5.458120569873176, 5.521587088127515, 5.585053606381854, 5.648520124636194, 5.711986642890533, 5.775453161144872, 5.838919679399211, 5.902386197653551, 5.96585271590789, 6.029319234162229, 6.092785752416569, 6.156252270670908, 6.219718788925247, 6.283185307179586], "xaxis": "x", "y": [1.0, 1.4630795833682328, 2.1373243038955634, 3.1127527588691386, 4.512665157938811, 6.502590748549505, 9.299631111681869, 13.180908706135929, 18.48908238632809, 25.63208545332506, 35.07356014255604, 47.31018774898056, 62.832601371532455, 82.06817070500203, 105.30688332906485, 132.61573187451685, 163.75191673472528, 198.0897440304272, 234.57889537329808, 271.7512597243181, 307.7886815586311, 340.6547189622888, 368.2811047140857, 388.78666990218437, 400.69640071076407, 403.1242253933208, 395.8869361488136, 379.5281047043677, 355.24748139707503, 324.7491218151417, 290.0359591284001, 253.1863463954536, 216.1478459969528, 180.57612295783417, 147.7348521939917, 118.45948971524204, 93.17667723593001, 71.96393050431264, 54.63168376024866, 40.81109241286118, 30.034874300018654, 21.803365736063487, 15.632610208030695, 11.084893244996108, 7.784393219238953, 5.421623671889371, 3.750402609374498, 2.5805650222801164, 1.768861748583947, 1.2096942007178353, 0.8266551988152018, 0.5653353071830195, 0.3875120337469451, 0.2666380397401611, 0.18444659026868804, 0.12846216420934695, 0.09021286699819275, 0.06396884376265503, 0.04586447854451969, 0.033294629103854126, 0.02450314218212056, 0.01830439648150887, 0.013895850226525246, 0.0107322994301 ...

# %% [markdown]
# # Problem 2: Zooming In on Data

# %%
# This changes the width of the entire figure
fig.update_layout(xaxis = {'domain':[0.0,1.0]})

# This changes the x-limits
fig.update_layout(xaxis = {'range':[0,2*np.pi]})

# Update figure title
fig.update_layout(title = {'text': "Example Plot 2"})

# Update the y-axis range
fig.update_layout(yaxis = {'range': [0,1]})
# Out:
# <div>                            <div id="6aa2bcb3-d540-467e-a909-8c324ba82741" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6aa2bcb3-d540-467e-a909-8c324ba82741")) {                    Plotly.newPlot(                        "6aa2bcb3-d540-467e-a909-8c324ba82741",                        [{"hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "Green", "dash": "solid", "width": 4}, "marker": {"color": "Green", "size": 10}, "mode": "markers+lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [0.0, 0.06346651825433926, 0.12693303650867852, 0.1903995547630178, 0.25386607301735703, 0.3173325912716963, 0.3807991095260356, 0.4442656277803748, 0.5077321460347141, 0.5711986642890533, 0.6346651825433925, 0.6981317007977318, 0.7615982190520711, 0.8250647373064104, 0.8885312555607496, 0.9519977738150889, 1.0154642920694281, 1.0789308103237674, 1.1423973285781066, 1.2058638468324459, 1.269330365086785, 1.3327968833411243, 1.3962634015954636, 1.4597299198498028, 1.5231964381041423, 1.5866629563584815, 1.6501294746128208, 1.71359599286716, 1.7770625111214993, 1.8405290293758385, 1.9039955476301778, 1.967462065884517, 2.0309285841388562, 2.0943951023931957, 2.1578616206475347, 2.221328138901874, 2.284794657156213, 2.3482611754105527, 2.4117276936648917, 2.475194211919231, 2.53866073017357, 2.6021272484279097, 2.6655937666822487, 2.729060284936588, 2.792526803190927, 2.8559933214452666, 2.9194598396996057, 2.982926357953945, 3.0463928762082846, 3.1098593944626236, 3.173325912716963, 3.236792430971302, 3.3002589492256416, 3.3637254674799806, 3.42719198573432, 3.490658503988659, 3.5541250222429985, 3.6175915404973376, 3.681058058751677, 3.744524577006016, 3.8079910952603555, 3.8714576135146945, 3.934924131769034, 3.998390650023373, 4.0618571682777125, 4.1253236865320515, 4.188790204786391, 4.25225672304073, 4.3157232412950695, 4.3791897595494085, 4.442656277803748, 4.506122796058087, 4.569589314312426, 4.6330558325667655, 4.696522350821105, 4.759988869075444, 4.823455387329783, 4.886921905584122, 4.950388423838462, 5.013854942092801, 5.07732146034714, 5.14078797860148, 5.204254496855819, 5.267721015110158, 5.331187533364497, 5.394654051618837, 5.458120569873176, 5.521587088127515, 5.585053606381854, 5.648520124636194, 5.711986642890533, 5.775453161144872, 5.838919679399211, 5.902386197653551, 5.96585271590789, 6.029319234162229, 6.092785752416569, 6.156252270670908, 6.219718788925247, 6.283185307179586], "xaxis": "x", "y": [1.0, 1.4630795833682328, 2.1373243038955634, 3.1127527588691386, 4.512665157938811, 6.502590748549505, 9.299631111681869, 13.180908706135929, 18.48908238632809, 25.63208545332506, 35.07356014255604, 47.31018774898056, 62.832601371532455, 82.06817070500203, 105.30688332906485, 132.61573187451685, 163.75191673472528, 198.0897440304272, 234.57889537329808, 271.7512597243181, 307.7886815586311, 340.6547189622888, 368.2811047140857, 388.78666990218437, 400.69640071076407, 403.1242253933208, 395.8869361488136, 379.5281047043677, 355.24748139707503, 324.7491218151417, 290.0359591284001, 253.1863463954536, 216.1478459969528, 180.57612295783417, 147.7348521939917, 118.45948971524204, 93.17667723593001, 71.96393050431264, 54.63168376024866, 40.81109241286118, 30.034874300018654, 21.803365736063487, 15.632610208030695, 11.084893244996108, 7.784393219238953, 5.421623671889371, 3.750402609374498, 2.5805650222801164, 1.768861748583947, 1.2096942007178353, 0.8266551988152018, 0.5653353071830195, 0.3875120337469451, 0.2666380397401611, 0.18444659026868804, 0.12846216420934695, 0.09021286699819275, 0.06396884376265503, 0.04586447854451969, 0.033294629103854126, 0.02450314218212056, 0.01830439648150887, 0.013895850226525246, 0.0107322994301 ...

# %% [markdown]
# # Problem 3: Importing Data

# %%
# Clearing variables
del fig
del x
del y

# %%
data = np.loadtxt('Supplementary Files/Preliminaries/NoisyFunction.dat')

# %%
t = data[:,0]
y = data[:,1]

q = np.log(y**2)

# %%
fig = px.scatter(x=t, y=q)

# Updating the format
fig.update_layout(
    title = {
        'text': "Example Plot 3",
        'y': 0.95,
        'x': 0.5,
        'xanchor': 'center',
        'yanchor': 'top',
        'font': dict(family = "Arial", size = 30)
    },
    xaxis = {
        'title': "t",
        'title_font': dict(family = "Arial", size = 24)
    },
    yaxis = {
        'title': "log(y^2)",
        'title_font': dict(family = "Arial", size = 24)
    })

# This can change the background color
fig.update_layout({'plot_bgcolor': 'rgba(0, 0, 0, 0.1)','paper_bgcolor': 'rgba(0, 0, 0, 0)'})

fig.show()
# Out:
# <div>                            <div id="25adb3a3-777b-4a8f-8403-0cd2afc870a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25adb3a3-777b-4a8f-8403-0cd2afc870a9")) {                    Plotly.newPlot(                        "25adb3a3-777b-4a8f-8403-0cd2afc870a9",                        [{"hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [0.0, 0